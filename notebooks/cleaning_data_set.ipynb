# %%
import numpy as np
import pandas as pd
import rename_columns
from  clean_string_content import clean_strings
import duplicate
import matplotlib.pyplot as plt
import seaborn as sns
from box_plot import box_plot
import functions_Ako
import yaml

# %%
try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("Configuration file not found")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv(config['input_data']['file'])
df
# Out:
#                Game Title      Genre         Platform Release Year  \
# 0         Pixel Odyssey 2     Action      PlayStation         2024
# 1       Battle Warriors 4   Strategy   Cross-Platform         2024
# 2      Legends of Valor 2    Shooter             Xbox         2024
# 3         Shadow Realms 4     Action  Nintendo Switch         2024
# 4           Cyber Quest 2  Adventure             Xbox         2024
# ..                    ...        ...              ...          ...
# 995  Warzone Chronicles 1     Horror  Nintendo Switch         2000
# 996     Zombie Outbreak 3   Fighting   Cross-Platform         2000
# 997     Battle Warriors 5   Fighting               PC         2000
# 998         Cyber Quest 2  Adventure   Cross-Platform         2000
# 999    Legends of Valor 2  Adventure             Xbox         2000
#
#        Developer  Revenue (Millions $)  Players (Millions)  \
# 0    Square Enix               1847.58               44.96
# 1             EA               4835.79              115.65
# 2    Square Enix               2628.55              169.67
# 3      Microsoft               1695.50              184.40
# 4      Microsoft               4529.75               17.28
# ..           ...                   ...                 ...
# 995      Ubisoft               2654.16              174.49
# 996      Ubisoft               2170.46              155.20
# 997     Rockstar               2040.85              166.01
# 998   Activision               2657.88              112.92
# 999    Microsoft               4030.54                3.73
#
#      Peak Concurrent Players  Metacritic Score Esports Popularity  \
# 0                      14.07                87                Yes
# 1                      56.27                92                Yes
# 2                      74.74                99                 No
# 3                      20.15                73                Yes
# 4                       5.83                91                Yes
# ..                       ...               ...                ...
# 995                    22.38                53                Yes
# 996                    74.51                57                Yes
# 997                    50.85                82                 No
# 998                    25.93                66                 No
# 999                     0.77                90                 No
#
#     Trending Status
# 0         Declining
# 1            Stable
# 2         Declining
# 3            Stable
# 4            Stable
# ..              ...
# 995          Stable
# 996       Declining
# 997          Rising
# 998          Rising
# 999          Stable
#
# [1000 rows x 11 columns]

# %%
# # Checking for Null Values

df.isnull()
# Out:
#      Game Title  Genre  Platform  Release Year  Developer  \
# 0         False  False     False         False      False
# 1         False  False     False         False      False
# 2         False  False     False         False      False
# 3         False  False     False         False      False
# 4         False  False     False         False      False
# ..          ...    ...       ...           ...        ...
# 995       False  False     False         False      False
# 996       False  False     False         False      False
# 997       False  False     False         False      False
# 998       False  False     False         False      False
# 999       False  False     False         False      False
#
#      Revenue (Millions $)  Players (Millions)  Peak Concurrent Players  \
# 0                   False               False                    False
# 1                   False               False                    False
# 2                   False               False                    False
# 3                   False               False                    False
# 4                   False               False                    False
# ..                    ...                 ...                      ...
# 995                 False               False                    False
# 996                 False               False                    False
# 997                 False               False                    False
# 998                 False               False                    False
# 999                 False               False                    False
#
#      Metacritic Score  Esports Popularity  Trending Status
# 0               False               False            False
# 1               False               False            False
# 2               False               False            False
# 3               False               False            False
# 4               False               False            False
# ..                ...                 ...              ...
# 995             False               False            False
# 996             False               False            False
# 997             False               False            False
# 998             False               False            False
# 999             False               False            False
#
# [1000 rows x 11 columns]

# %%
# # Check for null values in each column
df.isna().any()
# Out:
# Game Title                 False
# Genre                      False
# Platform                   False
# Release Year               False
# Developer                  False
# Revenue (Millions $)       False
# Players (Millions)         False
# Peak Concurrent Players    False
# Metacritic Score           False
# Esports Popularity         False
# Trending Status            False
# dtype: bool

# %%
# # Count the number of null values in each column
df.isna().sum()
# Out:
# Game Title                 0
# Genre                      0
# Platform                   0
# Release Year               0
# Developer                  0
# Revenue (Millions $)       0
# Players (Millions)         0
# Peak Concurrent Players    0
# Metacritic Score           0
# Esports Popularity         0
# Trending Status            0
# dtype: int64

# %%
# Drop column 'Peak Concurrent Players'
df.drop('Peak Concurrent Players', axis=1, inplace=True)
df.head()
# Out:
#            Game Title      Genre         Platform Release Year    Developer  \
# 0     Pixel Odyssey 2     Action      PlayStation         2024  Square Enix
# 1   Battle Warriors 4   Strategy   Cross-Platform         2024           EA
# 2  Legends of Valor 2    Shooter             Xbox         2024  Square Enix
# 3     Shadow Realms 4     Action  Nintendo Switch         2024    Microsoft
# 4       Cyber Quest 2  Adventure             Xbox         2024    Microsoft
#
#    Revenue (Millions $)  Players (Millions)  Metacritic Score  \
# 0               1847.58               44.96                87
# 1               4835.79              115.65                92
# 2               2628.55              169.67                99
# 3               1695.50              184.40                73
# 4               4529.75               17.28                91
#
#   Esports Popularity Trending Status
# 0                Yes       Declining
# 1                Yes          Stable
# 2                 No       Declining
# 3                Yes          Stable
# 4                Yes          Stable

# %%
# Drop column 'Esports Popularity'
df.drop('Esports Popularity', axis=1, inplace=True)
df.head()
# Out:
#            Game Title      Genre         Platform Release Year    Developer  \
# 0     Pixel Odyssey 2     Action      PlayStation         2024  Square Enix
# 1   Battle Warriors 4   Strategy   Cross-Platform         2024           EA
# 2  Legends of Valor 2    Shooter             Xbox         2024  Square Enix
# 3     Shadow Realms 4     Action  Nintendo Switch         2024    Microsoft
# 4       Cyber Quest 2  Adventure             Xbox         2024    Microsoft
#
#    Revenue (Millions $)  Players (Millions)  Metacritic Score Trending Status
# 0               1847.58               44.96                87       Declining
# 1               4835.79              115.65                92          Stable
# 2               2628.55              169.67                99       Declining
# 3               1695.50              184.40                73          Stable
# 4               4529.75               17.28                91          Stable

# %%
# # Drop column 'Trending Status'
df.drop('Trending Status', axis=1, inplace=True)
df.head()
# Out:
#            Game Title      Genre         Platform Release Year    Developer  \
# 0     Pixel Odyssey 2     Action      PlayStation         2024  Square Enix
# 1   Battle Warriors 4   Strategy   Cross-Platform         2024           EA
# 2  Legends of Valor 2    Shooter             Xbox         2024  Square Enix
# 3     Shadow Realms 4     Action  Nintendo Switch         2024    Microsoft
# 4       Cyber Quest 2  Adventure             Xbox         2024    Microsoft
#
#    Revenue (Millions $)  Players (Millions)  Metacritic Score
# 0               1847.58               44.96                87
# 1               4835.79              115.65                92
# 2               2628.55              169.67                99
# 3               1695.50              184.40                73
# 4               4529.75               17.28                91

# %%
column_map = {
    'Game Title': 'game_title', 
    'Genre': 'genre', 
    'Platform': 'platform', 
    'Release Year': 'release_year', 
    'Developer': 'developer', 
    'Revenue (Millions $)': 'revenue_millions', 
    'Players (Millions)': 'players_millions',
    'Metacritic Score': 'metacritic_score'
}
df = rename_columns.rename_multiple_columns(df, column_map)
df
# Out:
#                game_title      genre         platform release_year  \
# 0         Pixel Odyssey 2     Action      PlayStation         2024
# 1       Battle Warriors 4   Strategy   Cross-Platform         2024
# 2      Legends of Valor 2    Shooter             Xbox         2024
# 3         Shadow Realms 4     Action  Nintendo Switch         2024
# 4           Cyber Quest 2  Adventure             Xbox         2024
# ..                    ...        ...              ...          ...
# 995  Warzone Chronicles 1     Horror  Nintendo Switch         2000
# 996     Zombie Outbreak 3   Fighting   Cross-Platform         2000
# 997     Battle Warriors 5   Fighting               PC         2000
# 998         Cyber Quest 2  Adventure   Cross-Platform         2000
# 999    Legends of Valor 2  Adventure             Xbox         2000
#
#        developer  revenue_millions  players_millions  metacritic_score
# 0    Square Enix           1847.58             44.96                87
# 1             EA           4835.79            115.65                92
# 2    Square Enix           2628.55            169.67                99
# 3      Microsoft           1695.50            184.40                73
# 4      Microsoft           4529.75             17.28                91
# ..           ...               ...               ...               ...
# 995      Ubisoft           2654.16            174.49                53
# 996      Ubisoft           2170.46            155.20                57
# 997     Rockstar           2040.85            166.01                82
# 998   Activision           2657.88            112.92                66
# 999    Microsoft           4030.54              3.73                90
#
# [1000 rows x 8 columns]

# %%
text_cols = df.select_dtypes(include="object").columns
df[text_cols]= df[text_cols].applymap(clean_strings)
df[text_cols]
# Out:
# C:\Users\davyg\AppData\Local\Temp\ipykernel_21612\1150974337.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[text_cols]= df[text_cols].applymap(clean_strings)
#                game_title      genre         platform release_year  \
# 0         pixel odyssey 2     action      playstation         2024
# 1       battle warriors 4   strategy   cross platform         2024
# 2      legends of valor 2    shooter             xbox         2024
# 3         shadow realms 4     action  nintendo switch         2024
# 4           cyber quest 2  adventure             xbox         2024
# ..                    ...        ...              ...          ...
# 995  warzone chronicles 1     horror  nintendo switch         2000
# 996     zombie outbreak 3   fighting   cross platform         2000
# 997     battle warriors 5   fighting               pc         2000
# 998         cyber quest 2  adventure   cross platform         2000
# 999    legends of valor 2  adventure             xbox         2000
#
#        developer
# 0    square enix
# 1             ea
# 2    square enix
# 3      microsoft
# 4      microsoft
# ..           ...
# 995      ubisoft
# 996      ubisoft
# 997     rockstar
# 998   activision
# 999    microsoft
#
# [1000 rows x 5 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
# Remove duplicate rows
df = duplicate.remove_duplicate_rows(df, keep="first")
display(df)
# Out:
#                game_title      genre         platform release_year  \
# 0         pixel odyssey 2     action      playstation         2024
# 1       battle warriors 4   strategy   cross platform         2024
# 2      legends of valor 2    shooter             xbox         2024
# 3         shadow realms 4     action  nintendo switch         2024
# 4           cyber quest 2  adventure             xbox         2024
# ..                    ...        ...              ...          ...
# 995  warzone chronicles 1     horror  nintendo switch         2000
# 996     zombie outbreak 3   fighting   cross platform         2000
# 997     battle warriors 5   fighting               pc         2000
# 998         cyber quest 2  adventure   cross platform         2000
# 999    legends of valor 2  adventure             xbox         2000
#
#        developer  revenue_millions  players_millions  metacritic_score
# 0    square enix           1847.58             44.96                87
# 1             ea           4835.79            115.65                92
# 2    square enix           2628.55            169.67                99
# 3      microsoft           1695.50            184.40                73
# 4      microsoft           4529.75             17.28                91
# ..           ...               ...               ...               ...
# 995      ubisoft           2654.16            174.49                53
# 996      ubisoft           2170.46            155.20                57
# 997     rockstar           2040.85            166.01                82
# 998   activision           2657.88            112.92                66
# 999    microsoft           4030.54              3.73                90
#
# [1000 rows x 8 columns]

# %%
df.describe()
# Out:
#        revenue_millions  players_millions  metacritic_score
# count       1000.000000       1000.000000       1000.000000
# mean        2483.017800        103.499820         74.990000
# std         1412.629451         58.869562         14.618536
# min           11.430000          0.530000         50.000000
# 25%         1276.190000         52.005000         62.000000
# 50%         2476.130000        107.040000         76.000000
# 75%         3677.797500        155.632500         87.000000
# max         4999.790000        199.980000        100.000000

# %%
box_plot(df, column ="revenue_millions", title="revenue in millions dollars", color="skyblue")

# %%
box_plot(df, column ="players_millions", title="number of players", color="skyblue")

# %%
box_plot(df, column ="metacritic_score", title="the metacritic score", color="skyblue")

# %%
df = functions_Ako.index_reset(df)
df
# Out:
#                 game_title      genre         platform release_year  \
# 1          pixel odyssey 2     action      playstation         2024
# 2        battle warriors 4   strategy   cross platform         2024
# 3       legends of valor 2    shooter             xbox         2024
# 4          shadow realms 4     action  nintendo switch         2024
# 5            cyber quest 2  adventure             xbox         2024
# ...                    ...        ...              ...          ...
# 996   warzone chronicles 1     horror  nintendo switch         2000
# 997      zombie outbreak 3   fighting   cross platform         2000
# 998      battle warriors 5   fighting               pc         2000
# 999          cyber quest 2  adventure   cross platform         2000
# 1000    legends of valor 2  adventure             xbox         2000
#
#         developer  revenue_millions  players_millions  metacritic_score
# 1     square enix           1847.58             44.96                87
# 2              ea           4835.79            115.65                92
# 3     square enix           2628.55            169.67                99
# 4       microsoft           1695.50            184.40                73
# 5       microsoft           4529.75             17.28                91
# ...           ...               ...               ...               ...
# 996       ubisoft           2654.16            174.49                53
# 997       ubisoft           2170.46            155.20                57
# 998      rockstar           2040.85            166.01                82
# 999    activision           2657.88            112.92                66
# 1000    microsoft           4030.54              3.73                90
#
# [1000 rows x 8 columns]

# %%
# cleaning date convert the  string type into integer 
df["release_year"] = df["release_year"].astype(str).str.strip().str.replace(" ", "")
df["release_year"] = df["release_year"].astype(int)

# %% [markdown]
# # Data analysis

# %%
#Q1.Which platform has the highest average revenue per game? 

rev_per_game  = df.groupby(['platform', 'game_title'])['revenue_millions'].mean()
rev_per_game_df = rev_per_game.reset_index()
print(type(rev_per_game_df))
rev_per_game_df.sort_values(by='revenue_millions', ascending=False) 
rev_per_game_df.head(100)

mean_revenue_sorted = (
    rev_per_game_df.groupby('platform')['revenue_millions']
    .mean()
    .sort_values(ascending=False)
)

print(mean_revenue_sorted)

mean_revenue_sorted_df = mean_revenue_sorted.reset_index()
print(type(mean_revenue_sorted_df))
display(mean_revenue_sorted_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# platform
# nintendo switch    2606.145069
# mobile             2548.546331
# cross platform     2500.658914
# xbox               2460.337939
# pc                 2459.780791
# playstation        2372.401521
# Name: revenue_millions, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
#           platform  revenue_millions
# 0  nintendo switch       2606.145069
# 1           mobile       2548.546331
# 2   cross platform       2500.658914
# 3             xbox       2460.337939
# 4               pc       2459.780791
# 5      playstation       2372.401521

# %%
#which has the highest median revenue per game
median_revenue_sorted = (
    rev_per_game_df.groupby('platform')['revenue_millions']
    .median()
    .sort_values(ascending=False)
)

print(median_revenue_sorted)

median_revenue_sorted_df = median_revenue_sorted.reset_index()
print(type(median_revenue_sorted_df))
display(median_revenue_sorted_df)
# Out:
# platform
# mobile             2593.550000
# nintendo switch    2578.100833
# cross platform     2472.650000
# pc                 2447.620833
# xbox               2388.647500
# playstation        2338.268250
# Name: revenue_millions, dtype: float64
# <class 'pandas.core.frame.DataFrame'>
#           platform  revenue_millions
# 0           mobile       2593.550000
# 1  nintendo switch       2578.100833
# 2   cross platform       2472.650000
# 3               pc       2447.620833
# 4             xbox       2388.647500
# 5      playstation       2338.268250

# %%
import matplotlib.pyplot as plt



filtered_df =median_revenue_sorted_df[
    (median_revenue_sorted_df['platform'] == 'nintendo switch') |
    (median_revenue_sorted_df['platform'] == 'cross platform') |
    (median_revenue_sorted_df['platform'] == 'playstation') |
    (median_revenue_sorted_df['platform'] == 'xbox')
]

print(filtered_df)

filtered_df = filtered_df.reset_index()
print(type(filtered_df))

platforms = filtered_df['platform']
median = filtered_df['revenue_millions']
mean = median_revenue_sorted_df['revenue_millions']

plt.figure(figsize=(8, 6)) # Set size for better viewing
plt.bar(platforms, median, color=['#dd3d6e','#6abfda', '#9e9e9e', '#5f8185'])

plt.xlabel('platform')
plt.ylabel('Revenue Median')
plt.title('Game Title Revenue Median per Platform')

plt.show()
# Out:
#           platform  revenue_millions
# 1  nintendo switch       2578.100833
# 2   cross platform       2472.650000
# 4             xbox       2388.647500
# 5      playstation       2338.268250
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Overall, what is the correlation between Metacritic critic score and revenue?

# %%
correlation = df['metacritic_score'].corr(df['revenue_millions'])
print(correlation)
# Out:
# 0.01559465581129608

# %%
plt.scatter(df['metacritic_score'], df['revenue_millions'], c='#dd3d6e')
plt.xlabel('metacritic_score')
plt.ylabel('revenue_millions')
plt.title('Correlation between Metacritic Score and Revenue')
plt.show()

# %%
df['metacritic_score'] = df['metacritic_score'].astype(float)
df['revenue_millions'] = df['revenue_millions'].astype(float)

# %%
sns.regplot(x='metacritic_score', y='revenue_millions', data=df, scatter_kws={'color': '#dd3d6e'})
plt.title('Metacritic Score vs Revenue')
plt.show()

# %% [markdown]
# # Is there a “threshold” score (for example, above 80) after which median revenue increases sharply?
#  We are putting the scores in bins like 0–69, 70–79, 80–89, 90+.​¶

# %%
bins = [0, 69, 79, 89, 100]
labels = ['0-69', '70-79', '80-89', '90+']

# %%
df['Score_Bin'] = pd.cut(df['metacritic_score'], bins=bins, labels=labels, right=True)

# %%
df.head()
# Out:
#            game_title      genre         platform  release_year    developer  \
# 1     pixel odyssey 2     action      playstation          2024  square enix
# 2   battle warriors 4   strategy   cross platform          2024           ea
# 3  legends of valor 2    shooter             xbox          2024  square enix
# 4     shadow realms 4     action  nintendo switch          2024    microsoft
# 5       cyber quest 2  adventure             xbox          2024    microsoft
#
#    revenue_millions  players_millions  metacritic_score Score_Bin
# 1           1847.58             44.96              87.0     80-89
# 2           4835.79            115.65              92.0       90+
# 3           2628.55            169.67              99.0       90+
# 4           1695.50            184.40              73.0     70-79
# 5           4529.75             17.28              91.0       90+

# %%
median_revenue_by_bin = df.groupby('Score_Bin')['revenue_millions'].median().reset_index()

print(median_revenue_by_bin)
# Out:
#   Score_Bin  revenue_millions
# 0      0-69          2496.760
# 1     70-79          2241.105
# 2     80-89          2588.840
# 3       90+          2577.560
# C:\Users\davyg\AppData\Local\Temp\ipykernel_21612\1955155442.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   median_revenue_by_bin = df.groupby('Score_Bin')['revenue_millions'].median().reset_index()

# %%
sns.barplot(
    x='Score_Bin',
    y='revenue_millions',
    data=df,
    estimator=np.median,
    ci=None, color='#dd3d6e'
)
plt.title('Median Revenue by Metacritic Score Bin')
plt.ylabel('Median Revenue (Millions $)')
plt.xlabel('Metacritic Score Range')
plt.show()
# Out:
# C:\Users\davyg\AppData\Local\Temp\ipykernel_21612\2586446224.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# # Portfolio and investment decision questions

# %% [markdown]
# # Which companies achieved a Metacritic score above 80 ?

# %%
high_score_games = df[df['metacritic_score'] > 80]
companies_above_80 = high_score_games['developer'].unique()
company_counts = high_score_games['developer'].value_counts()
print(company_counts)
# Out:
# developer
# sony            47
# microsoft       46
# rockstar        45
# square enix     44
# capcom          44
# ubisoft         39
# activision      37
# ea              35
# bandai namco    34
# nintendo        32
# Name: count, dtype: int64

# %%
# 1. Filter games with score > 80
filtered_df = df[df["metacritic_score"] > 80]

# 2. Count the number of games of the company
company_counts = filtered_df["developer"].value_counts().head(5)

# 3. Visualization
plt.figure(figsize=(10,6))
company_counts.plot(kind='bar', color=['#dd3d6e','#6abfda', '#9e9e9e', '#5f8185', '#4c566a'])
plt.title("Companies with Metacritic Scores Above 80")
plt.xlabel("platform")
plt.ylabel("Number of High-Scoring Games")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Which companies delivered the best revenue

# %%
# Which companies delivered the best revenue 
# 1. Calculate the total revenue for each company
top5_revenue = (
    df.groupby("developer")["revenue_millions"]
           .sum()
           .sort_values(ascending=False)
           .head(5)
)

print(top5_revenue)
# Out:
# developer
# sony          320316.24
# activision    273990.20
# rockstar      259235.71
# capcom        259007.30
# microsoft     253175.67
# Name: revenue_millions, dtype: float64

# %%
# 2. Visualization : TOP 5
plt.figure(figsize=(12,6))
top5_revenue.head(5).plot(kind='bar', color=['#dd3d6e','#6abfda','#9e9e9e', '#5f8185', '#4c566a'])
plt.title("Top 5 Companies by Total Revenue")
plt.xlabel("Company")
plt.ylabel("Total Revenue (millions)")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # What is the total player base of the genre ?

# %%
genre_players = df.groupby('genre')['players_millions'].sum()
genre_players.unique()
genre_players.sort_values(ascending=False)
# Out:
# genre
# action        13051.70
# strategy      12382.01
# sports        11264.45
# fighting      11050.45
# racing        10156.80
# horror         9891.97
# simulation     9736.62
# shooter        9664.59
# adventure      8704.35
# rpg            7596.88
# Name: players_millions, dtype: float64

# %%
genre_players = df.groupby('genre')['players_millions'].sum().sort_values(ascending=False)

# Plot 1: Players by Genre
plt.figure(figsize=(10,5))
genre_players.plot(kind="bar", color=['#dd3d6e','#6abfda','#dd3d6e','#6abfda', '#dd3d6e','#6abfda','#dd3d6e','#6abfda','#dd3d6e','#6abfda'])
plt.title("Total Players by Genre")
plt.xlabel("Genre")
plt.ylabel("Players (Millions)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # What is the distribution of players by platform?

# %%
df
# Out:
#                 game_title      genre         platform  release_year  \
# 1          pixel odyssey 2     action      playstation          2024
# 2        battle warriors 4   strategy   cross platform          2024
# 3       legends of valor 2    shooter             xbox          2024
# 4          shadow realms 4     action  nintendo switch          2024
# 5            cyber quest 2  adventure             xbox          2024
# ...                    ...        ...              ...           ...
# 996   warzone chronicles 1     horror  nintendo switch          2000
# 997      zombie outbreak 3   fighting   cross platform          2000
# 998      battle warriors 5   fighting               pc          2000
# 999          cyber quest 2  adventure   cross platform          2000
# 1000    legends of valor 2  adventure             xbox          2000
#
#         developer  revenue_millions  players_millions  metacritic_score  \
# 1     square enix           1847.58             44.96              87.0
# 2              ea           4835.79            115.65              92.0
# 3     square enix           2628.55            169.67              99.0
# 4       microsoft           1695.50            184.40              73.0
# 5       microsoft           4529.75             17.28              91.0
# ...           ...               ...               ...               ...
# 996       ubisoft           2654.16            174.49              53.0
# 997       ubisoft           2170.46            155.20              57.0
# 998      rockstar           2040.85            166.01              82.0
# 999    activision           2657.88            112.92              66.0
# 1000    microsoft           4030.54              3.73              90.0
#
#      Score_Bin
# 1        80-89
# 2          90+
# 3          90+
# 4        70-79
# 5          90+
# ...        ...
# 996       0-69
# 997       0-69
# 998      80-89
# 999       0-69
# 1000       90+
#
# [1000 rows x 9 columns]

# %%
platform_df = df[
    (df['platform'] == 'nintendo switch') |
    (df['platform'] == 'cross platform') |
    (df['platform'] == 'playstation') |
    (df['platform'] == 'xbox')
]
platform_players = platform_df.groupby('platform')['players_millions'].sum().sort_values(ascending=False)
platform_players.unique()
platform_players
# Out:
# platform
# playstation        18408.82
# cross platform     18158.33
# xbox               17840.07
# nintendo switch    15023.83
# Name: players_millions, dtype: float64

# %%
# Plot 2: Players by Console/Platform

plt.figure(figsize=(10,5))
platform_players.plot(kind='bar', color = ['#dd3d6e','#6abfda','#9e9e9e', '#5f8185'])
plt.title("Total Players by Platform")
plt.xlabel("Platform")
plt.ylabel("Players (Millions)")
plt.tight_layout()
plt.show()
